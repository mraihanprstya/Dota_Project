# %% [markdown]
# <a href="https://colab.research.google.com/github/mraihanprstya/Dota_Project/blob/master/Data/ScrapingDataDotaColabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update; apt install php; apt install chromium-browser; pip install rpa

import rpa as r; r.setup(); r.dump(r.load('/root/.tagui/src/tagui').replace('"google-chrome"', '"chromium-browser"').replace('--disable-gpu', '--disable-gpu --no-sandbox'), '/root/.tagui/src/tagui')
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [61.8 kB]
# ...

# %%
import pandas as pd
import numpy as np
import time
import random
from google.colab import drive
drive.mount('/content/drive')

df = pd.DataFrame(columns=['IDmatch',
                           'Team',
                           'Carry',
                           'P_Carry',
                           'Mid',
                           'P_Mid',
                           'Offlane',
                           'P_Offlane',
                           'Sup',
                           'P_Sup',
                           'Hsup',
                           'P_Hsup',
                           'Enemy',
                           'ECarry',
                           'P_ECarry',
                           'EMid',
                           'P_EMid',
                           'EOfflane',
                           'P_EOfflane',
                           'ESup',
                           'P_ESup',
                           'EHsup',
                           'P_EHsup',
                           'win',
                           'Date'])

banlom = len(df.columns)

# %%
df = pd.read_excel('/content/drive/MyDrive/Dota/Raw_Data_afk.xlsx')

# %%
r.init(headless_mode = True)
r.url('https://www.dotabuff.com/esports/teams/39-evil-geniuses/matches')
for j in range(11,21):
  for i in range(20):
    print('Match ke-'+str((20*j)+i+1))
    match = [None]*banlom
    match[23] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/section[2]/article/table/tbody/tr['+str(i+1)+']/td[2]/div/a')
    link = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/section[2]/article/table/tbody/tr['+str(i+1)+']/td[2]/div/a/@href')
    link = 'https://www.dotabuff.com'+link
    r.url(link)
    match[0] = r.read('/html/body/div[1]/div[7]/div[3]/div[3]/div[1]/div[1]/div/h1')
    while match[0] is '':
      r.close()
      time.sleep(30+random.randint(0,30))
      r.init(headless_mode = True)
      r.url(link)
      match[0] = r.read('/html/body/div[1]/div[7]/div[3]/div[3]/div[1]/div[1]/div/h1')
    match[24] = r.read('/html/body/div[1]/div[7]/div[3]/div[3]/div[1]/div[2]/dl[5]/dd/time/@datetime')
    match[1] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/header/a/span[2]')
    match[12] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/header/a/span[2]')
    match[2] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[1]/td[1]/div/a/img/@oldtitle')
    match[4] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[2]/td[1]/div/a/img/@oldtitle')
    match[6] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[3]/td[1]/div/a/img/@oldtitle')
    match[8] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[4]/td[1]/div/a/img/@oldtitle')
    match[10] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[5]/td[1]/div/a/img/@oldtitle')
    match[3] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[1]/td[4]/a/span')
    match[5] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[2]/td[4]/a/span')
    match[7] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[3]/td[4]/a/span')
    match[9] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[4]/td[4]/a/span')
    match[11] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[5]/td[4]/a/span')
    match[13] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[1]/td[1]/div/a/img/@oldtitle')
    match[15] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[2]/td[1]/div/a/img/@oldtitle')
    match[17] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[3]/td[1]/div/a/img/@oldtitle')
    match[19] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[4]/td[1]/div/a/img/@oldtitle')
    match[21] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[5]/td[1]/div/a/img/@oldtitle')
    match[14] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[1]/td[4]/a/span')
    match[16] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[2]/td[4]/a/span')
    match[18] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[3]/td[4]/a/span')
    match[20] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[4]/td[4]/a/span')
    match[22] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[5]/td[4]/a/span')
    
    temp = pd.Series(match, index = df.columns)
    df = df.append(temp, ignore_index=True)
    r.url('https://www.dotabuff.com/esports/teams/39-evil-geniuses/matches?original_slug=39-evil-geniuses&page='+str(j+1))  
  df.to_excel('/content/drive/MyDrive/Dota/Raw_Data_afk.xlsx', index = False)
r.close()
# Out:
# Match ke-221
# Match ke-222
# Match ke-223
# Match ke-224
# Match ke-225
# Match ke-226
# Match ke-227
# Match ke-228
# Match ke-229
# Match ke-230
# Match ke-231
# Match ke-232
# Match ke-233
# Match ke-234
# Match ke-235
# Match ke-236
# Match ke-237
# Match ke-238
# Match ke-239
# Match ke-240
# Match ke-241
# Match ke-242
# Match ke-243
# Match ke-244
# Match ke-245
# Match ke-246
# Match ke-247
# Match ke-248
# Match ke-249
# Match ke-250
# Match ke-251
# [RPA][ERROR] - cannot find /html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[1]/td[4]/a/span
# [RPA][ERROR] - cannot find /html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[2]/td[4]/a/span
# [RPA][ERROR] - cannot find /html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[3]/td[4]/a/span
# [RPA][ERROR] - cannot find /html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[4]/td[4]/a/span
# ...

# %%
df
# Out:
#                       IDmatch  ...                       Date
# 0    Match 6031605579Overview  ...  2021-06-07T19:22:23+00:00
# 1    Match 6031515062Overview  ...  2021-06-07T18:19:06+00:00
# 2    Match 6030163065Overview  ...  2021-06-06T19:49:00+00:00
# 3    Match 6030086704Overview  ...  2021-06-06T18:43:58+00:00
# 4    Match 6029767740Overview  ...  2021-06-06T15:11:24+00:00
# ..                        ...  ...                        ...
# 215  Match 5205500820Overview  ...  2020-01-21T10:14:12+00:00
# 216  Match 5203599285Overview  ...  2020-01-19T20:05:35+00:00
# 217  Match 5203547625Overview  ...  2020-01-19T18:39:28+00:00
# 218  Match 5203467588Overview  ...  2020-01-19T17:43:55+00:00
# 219  Match 5203371854Overview  ...  2020-01-19T16:09:34+00:00
#
# [220 rows x 25 columns]

# %%
test = df.drop([121,122,123,124], axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-84de455bf541> in <module>()
# ----> 1 test = df.drop([121,122,123,124], axis=0)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
df.to_excel('/content/drive/MyDrive/Dota/Raw_Data_afk.xlsx', index = False)
from google.colab import files; files.download('Raw_Data_afk.xlsx')

# %%
# Out:
# Mounted at /content/drive
