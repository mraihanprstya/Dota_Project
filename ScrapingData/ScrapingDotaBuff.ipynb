# %%
import rpa as r
import pandas as pd
import numpy as np
import time
import random

# %% [markdown]
# Make DataFrame for scraping data

# %%
df = pd.DataFrame(columns=['IDmatch',
                           'Team',
                           'Carry',
                           'P_Carry',
                           'Mid',
                           'P_Mid',
                           'Offlane',
                           'P_Offlane',
                           'Sup',
                           'P_Sup',
                           'Hsup',
                           'P_Hsup',
                           'Enemy',
                           'ECarry',
                           'P_ECarry',
                           'EMid',
                           'P_EMid',
                           'EOfflane',
                           'P_EOfflane',
                           'ESup',
                           'P_ESup',
                           'EHsup',
                           'P_EHsup',
                           'win',
                           'Date'])

# %%
df = pd.read_excel('Rawdata/Raw_Data.xlsx')
banlom = len(df.columns)
panjang = int(len(df)/20)

# %%
r.init()
for j in range(panjang,51):
    r.url('https://www.dotabuff.com/esports/teams/39-evil-geniuses/matches?original_slug=39-evil-geniuses&page='+str(j+1))
    for i in range(20):
        print('Match ke-'+str((20*j)+i+1))
        match = [None]*banlom
        match[23] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/section[2]/article/table/tbody/tr['+str(i+1)+']/td[2]/div/a')
        link = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/section[2]/article/table/tbody/tr['+str(i+1)+']/td[2]/div/a/@href')
        link = 'https://www.dotabuff.com'+link
        r.url(link)
        match[0] = r.read('/html/body/div[1]/div[7]/div[3]/div[3]/div[1]/div[1]/div/h1')
        while match[0] is '':
            r.close()
            time.sleep(30+random.randint(0,30))
            r.init(headless_mode = True)
            r.url(link)
            match[0] = r.read('/html/body/div[1]/div[7]/div[3]/div[3]/div[1]/div[1]/div/h1')
        match[24] = r.read('/html/body/div[1]/div[7]/div[3]/div[3]/div[1]/div[2]/dl[5]/dd/time/@datetime')
        match[1] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/header/a/span[2]')
        match[12] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/header/a/span[2]')
        match[2] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[1]/td[1]/div/a/img/@oldtitle')
        match[4] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[2]/td[1]/div/a/img/@oldtitle')
        match[6] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[3]/td[1]/div/a/img/@oldtitle')
        match[8] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[4]/td[1]/div/a/img/@oldtitle')
        match[10] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[5]/td[1]/div/a/img/@oldtitle')
        match[3] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[1]/td[4]/a/span')
        match[5] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[2]/td[4]/a/span')
        match[7] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[3]/td[4]/a/span')
        match[9] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[4]/td[4]/a/span')
        match[11] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[5]/td[4]/a/span')
        match[13] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[1]/td[1]/div/a/img/@oldtitle')
        match[15] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[2]/td[1]/div/a/img/@oldtitle')
        match[17] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[3]/td[1]/div/a/img/@oldtitle')
        match[19] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[4]/td[1]/div/a/img/@oldtitle')
        match[21] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[5]/td[1]/div/a/img/@oldtitle')
        match[14] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[1]/td[4]/a/span')
        match[16] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[2]/td[4]/a/span')
        match[18] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[3]/td[4]/a/span')
        match[20] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[4]/td[4]/a/span')
        match[22] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[2]/article/table/tbody/tr[5]/td[4]/a/span')
        temp = pd.Series(match, index = df.columns)
        df = df.append(temp, ignore_index=True)
        r.url('https://www.dotabuff.com/esports/teams/39-evil-geniuses/matches?original_slug=39-evil-geniuses&page='+str(j+1)) 
    df.to_excel('Rawdata/Raw_Data.xlsx', index = False)
r.close()
# Out:
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-11-8caad5b60108>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   while match[0] is '':
# Match ke-221
# Match ke-222
# Match ke-223
# Match ke-224
# Match ke-225
# Match ke-226
# Match ke-227
# Match ke-228
# Match ke-229
# Match ke-230
# Match ke-231
# Match ke-232
# Match ke-233
# Match ke-234
# Match ke-235
# Match ke-236
# Match ke-237
# Match ke-238
# Match ke-239
# Match ke-240
# Match ke-241
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-8caad5b60108> in <module>
#      22         match[4] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[2]/td[1]/div/a/img/@oldtitle')
#      23         match[6] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[3]/td[1]/div/a/img/@oldtitle')
# ---> 24         match[8] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[4]/td[1]/div/a/img/@oldtitle')
#      25         match[10] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[5]/td[1]/div/a/img/@oldtitle')
#      26         match[3] = r.read('/html/body/div[1]/div[7]/div[3]/div[4]/div[1]/div[4]/section[1]/article/table/tbody/tr[1]/td[4]/a/span')
#
# C:\ProgramData\Anaconda3\lib\site-packages\tagui.py in read(element_identifier, test_coordinate1, test_coordinate2, test_coordinate3)
#    1120
#    1121     else:
# -> 1122         send('read ' + _sdq(element_identifier) + ' to read_result')
#    1123         send('dump read_result to rpa_python.txt')
#    1124         read_result = _tagui_output()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tagui.py in send(tagui_instruction)
#     801         # loop until tagui live mode is ready and listening for inputs
#     802         # also check _tagui_started to handle unexpected termination
# --> 803         while _tagui_started and not _ready(): pass
#     804         if not _tagui_started:
#     805             print('[RPA][ERROR] - TagUI process ended unexpectedly')
#
# C:\ProgramData\Anaconda3\lib\site-packages\tagui.py in _ready()
#     736
#     737         # read next line of output from tagui process live mode interface
# --> 738         tagui_out = _tagui_read()
#     739
#     740         # print to screen debug output that is saved to rpa_python.log
#
# C:\ProgramData\Anaconda3\lib\site-packages\tagui.py in _tagui_read()
#     122     """function to read from tagui process live mode interface"""
#     123     # readline instead of read, not expecting user input to tagui
# --> 124     global _process; return _py23_decode(_process.stdout.readline())
#     125
#     126 def _tagui_write(input_text = ''):
#
# KeyboardInterrupt:

# %%
df
# Out:
#                      IDmatch           Team        Carry          P_Carry  \
# 0   Match 6031605579Overview  Evil Geniuses        Viper       EG.Arteezy
# 1   Match 6031515062Overview  Evil Geniuses        Razor       EG.Arteezy
# 2   Match 6030163065Overview          Nigma         Lion           KuroKy
# 3   Match 6030086704Overview  Evil Geniuses   Naga Siren       EG.Arteezy
# 4   Match 6029767740Overview        PSG.LGD          Axe              昨夜书
# ..                       ...            ...          ...              ...
# 74  Match 5577029383Overview          Nigma    Anti-Mage  Liquid.Miracle-
# 75  Match 5997903024Overview  Evil Geniuses   Gyrocopter       EG.Arteezy
# 76  Match 5997852939Overview  Evil Geniuses         Luna       EG.Arteezy
# 77  Match 5997805507Overview    Quincy Crew  Wraith King     Newbee.Yawar
# 78  Match 5992735258Overview  Evil Geniuses         Luna       EG.Arteezy
#
#               Mid                P_Mid           Offlane         P_Offlane  \
# 0    Ember Spirit              EG.Abed         Clockwerk            EG.Fly
# 1        Batrider              EG.Abed              Lion            EG.Fly
# 2   Dragon Knight  Liquid.MinD_ContRoL              Luna       Spirit.ILTW
# 3    Ember Spirit              EG.Abed              Lion            EG.Fly
# 4            Lina         NothingToSay         Dark Seer  EHOME.Faith_bian
# ..            ...                  ...               ...               ...
# 74           Doom  Liquid.MinD_ContRoL           Warlock              rmN-
# 75   Storm Spirit              EG.Abed  Legion Commander            EG.Fly
# 76           Tiny              EG.Abed      Witch Doctor            EG.Fly
# 77        Leshrac          Newbee.CCnC           Slardar              -600
# 78        Leshrac              EG.Abed           Abaddon            EG.Fly
#
#               Sup             P_Sup  ...           EMid               P_EMid  \
# 0     Beastmaster  Fnatic.iceiceice  ...  Dragon Knight        Liquid.qojqva
# 1     Broodmother  Fnatic.iceiceice  ...  Dragon Knight        Liquid.qojqva
# 2         Phoenix         Liquid.gh  ...   Storm Spirit              EG.Abed
# 3     Broodmother  Fnatic.iceiceice  ...    Bristleback  Liquid.MinD_ContRoL
# 4    Nyx Assassin        EHOME.XinQ  ...  Dragon Knight              EG.Abed
# ..            ...               ...  ...            ...                  ...
# 74  Winter Wyvern         Liquid.gh  ...         Magnus           Gambit.gpk
# 75      Timbersaw  Fnatic.iceiceice  ...        Leshrac          Newbee.CCnC
# 76    Bristleback  Fnatic.iceiceice  ...       Snapfire          Newbee.CCnC
# 77       Hoodwink        Newbee.MSS  ...           Puck              EG.Abed
# 78    Bristleback  Fnatic.iceiceice  ...    Void Spirit         Pandas.Bryle
#
#               EOfflane                       P_EOfflane               ESup  \
# 0                 Luna                     Liquid.miCKe            Invoker
# 1                  Axe                     Liquid.miCKe       Shadow Fiend
# 2          Enchantress                           EG.Fly          Timbersaw
# 3               Magnus                      Spirit.ILTW        Dark Willow
# 4   Ancient Apparition                           EG.Fly               Mars
# ..                 ...                              ...                ...
# 74           Clockwerk                           EG.Fly        Beastmaster
# 75            Batrider                             -600        Enchantress
# 76           Necrophos                             -600          Clockwerk
# 77    Treant Protector                           EG.Fly  Centaur Warrunner
# 78                Mars  3333333333333333333333333333333            Warlock
#
#               P_ESup             EHsup          P_EHsup         win  \
# 0             Suma1L  Treant Protector    Liquid.Taiga❤  Lost Match
# 1             Suma1L       Enchantress    Liquid.Taiga❤   Won Match
# 2   Fnatic.iceiceice      Nyx Assassin         EG.Cr1t-  Lost Match
# 3          Liquid.gh              Puck  Liquid.Miracle-   Won Match
# 4   Fnatic.iceiceice          Snapfire         EG.Cr1t-  Lost Match
# ..               ...               ...              ...         ...
# 74      EG.Ramzes666            Rubick         EG.Cr1t-   Won Match
# 75        Newbee.MSS       Elder Titan              LoA  Lost Match
# 76        Newbee.MSS       Enchantress              LoA  Lost Match
# 77  Fnatic.iceiceice              Lina         EG.Cr1t-   Won Match
# 78              DuBu            Medusa       yatoro fan   Won Match
#
#                          Date
# 0   2021-06-07T19:22:23+00:00
# 1   2021-06-07T18:19:06+00:00
# 2   2021-06-06T19:49:00+00:00
# 3   2021-06-06T18:43:58+00:00
# 4   2021-06-06T15:11:24+00:00
# ..                        ...
# 74  2020-08-20T18:20:53+00:00
# 75  2021-05-17T01:24:55+00:00
# 76  2021-05-17T00:03:22+00:00
# 77  2021-05-16T22:35:19+00:00
# 78  2021-05-13T20:23:25+00:00
#
# [79 rows x 25 columns]

# %%
# r.init()
# r.url('https://www.dotabuff.com/matches/5794269880')
# print(r.read('/html/body/div[1]/div[7]/div[3]/div[3]/div[1]/div[1]/div/h1'))
r.close()
# Out:
# True
